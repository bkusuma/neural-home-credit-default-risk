# %% [markdown]
# # EDA

# %% [markdown]
# ## Library Import

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, classification_report, 
                             ConfusionMatrixDisplay)

from sklearn import set_config
set_config(transform_output="pandas")

from category_encoders import HashingEncoder

import sqlite3

from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, ConfusionMatrixDisplay

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import roc_auc_score, RocCurveDisplay, PrecisionRecallDisplay

import joblib

# %%
input_path = "../../kaggle/input/home-credit-default-risk/" # on local machine
# input_path = "/kaggle/input/home-credit-default-risk/" # on Kaggle

# con = sqlite3.connect(local_prepend + input_path + "home-credit-default-risk.sqlite") # connect to database
# pd.read_csv(local_prepend + input_path + "application_train.csv").to_sql("application_train", con, if_exists='append', index=False, index_label="SK_ID_CURR")

application_train = pd.read_csv(input_path + "application_train.csv")

# bureau_balance = pd.read_csv(local_prepend + input_path + "bureau_balance.csv")
bureau = pd.read_csv(input_path + "bureau.csv")
credit_card_balance = pd.read_csv(input_path + "credit_card_balance.csv")
# installments_payments = pd.read_csv(local_prepend + input_path + "installments_payments.csv")
POS_CASH_balance = pd.read_csv(input_path + "POS_CASH_balance.csv")
previous_application = pd.read_csv(input_path + "previous_application.csv")

# Description of columns in provided datasets
# HomeCredit_columns_description = pd.read_csv(local_prepend + input_path + "HomeCredit_columns_description.csv", encoding = "latin")

# # Test Data for later use
# application_test = pd.read_csv(local_prepend + input_path + "application_test.csv")

# %%
# dfs_to_merge = [bureau, previous_application, POS_CASH_balance, credit_card_balance]

# for df in dfs_to_merge:
#     application_train = pd.merge(application_train, df, how="inner", on="SK_ID_CURR")

# application_train.shape

# %%
application_train = pd.merge(application_train, bureau, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, previous_application, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, POS_CASH_balance, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, credit_card_balance, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])

# %%
application_train.select_dtypes(include='object')
# Out:
#         NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0                 Cash loans           M            N               Y
# 1                 Cash loans           F            N               N
# 2            Revolving loans           M            Y               Y
# 3                 Cash loans           F            N               Y
# 9                 Cash loans           M            N               Y
# ...                      ...         ...          ...             ...
# 3448566           Cash loans           M            N               N
# 3448567           Cash loans           F            N               Y
# 3448568           Cash loans           F            N               Y
# 3448569           Cash loans           F            N               Y
# 3448570           Cash loans           F            N               N
#
#         NAME_TYPE_SUITE_x      NAME_INCOME_TYPE  \
# 0           Unaccompanied               Working
# 1                  Family         State servant
# 2           Unaccompanied               Working
# 3           Unaccompanied               Working
# 9           Unaccompanied               Working
# ...                   ...                   ...
# 3448566     Unaccompanied               Working
# 3448567     Unaccompanied             Pensioner
# 3448568     Unaccompanied               Working
# 3448569     Unaccompanied  Commercial associate
# 3448570     Unaccompanied  Commercial associate
#
#                    NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0        Secondary / secondary special  Single / not married
# 1                     Higher education               Married
# 2        Secondary / secondary special  Single / not married
# 3        Secondary / secondary special        Civil marriage
# 9        Secondary / secondary special  Single / not married
# ...                                ...                   ...
# 3448566  Secondary / secondary special             Separated
# 3448567  Secondary / secondary special                 Widow
# 3448568               Higher education             Separated
# 3448569  Secondary / secondary special               Married
# 3448570               Higher education               Married
#
#          NAME_HOUSING_TYPE OCCUPATION_TYPE  ... NAME_CLIENT_TYPE  \
# 0        House / apartment        Laborers  ...              New
# 1        House / apartment      Core staff  ...         Repeater
# 2        House / apartment        Laborers  ...              New
# 3        House / apartment        Laborers  ...         Repeater
# 9        House / apartment      Core staff  ...         Repeater
# ...                    ...             ...  ...              ...
# 3448566       With parents     Sales staff  ...              New
# 3448567  House / apartment             NaN  ...              New
# 3448568  House / apartment        Managers  ...        Refreshed
# 3448569  House / apartment        Laborers  ...         Repeater
# 3448570  House / apartment        Laborers  ...        Refreshed
#
#           NAME_GOODS_CATEGORY NAME_PORTFOLIO NAME_PRODUCT_TYPE  \
# 0                    Vehicles            POS               XNA
# 1                         XNA           Cash            x-sell
# 2                      Mobile            POS               XNA
# 3                         XNA           Cash            x-sell
# 9                         XNA           Cash           walk-in
# ...                       ...            ...               ...
# 3448566                Mobile            POS               XNA
# 3448567  Consumer Electronics            POS               XNA
# 3448568                Mobile            POS               XNA
# 3448569             Computers            POS               XNA
# 3448570             Furniture            POS               XNA
#
#                     CHANNEL_TYPE  NAME_SELLER_INDUSTRY NAME_YIELD_GROUP  \
# 0                          Stone       Auto technology       low_normal
# 1        Credit and cash offices                   XNA       low_normal
# 2               Regional / Local          Connectivity           middle
# 3        Credit and cash offices                   XNA       low_normal
# 9               Regional / Local  Consumer electronics             high
# ...                          ...                   ...              ...
# 3448566             Country-wide          Connectivity             high
# 3448567             Country-wide  Consumer electronics       low_normal
# 3448568                    Stone          Connectivity             high
# 3448569             Country-wide  Consumer electronics       low_normal
# 3448570         Regional / Local             Furniture           middle
#
#                     PRODUCT_COMBINATION NAME_CONTRACT_STATUS_y  \
# 0               POS other with interest                 Active
# 1                      Cash X-Sell: low                 Active
# 2           POS mobile without interest                 Active
# 3                      Cash X-Sell: low                 Active
# 9                     Cash Street: high                 Active
# ...                                 ...                    ...
# 3448566        POS mobile with interest                 Signed
# 3448567  POS household without interest              Completed
# 3448568        POS mobile with interest                 Active
# 3448569     POS household with interest                 Active
# 3448570      POS industry with interest                 Active
#
#         NAME_CONTRACT_STATUS
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                     Active
# 9                        NaN
# ...                      ...
# 3448566                  NaN
# 3448567                  NaN
# 3448568                  NaN
# 3448569                  NaN
# 3448570                  NaN
#
# [307511 rows x 37 columns]

# %%
object_cols = application_train.select_dtypes(include='object').columns.to_list()

for col in object_cols:
    print(application_train[col].value_counts())
# Out:
# NAME_CONTRACT_TYPE_x
# Cash loans         278232
# Revolving loans     29279
# Name: count, dtype: int64
# CODE_GENDER
# F      202448
# M      105059
# XNA         4
# Name: count, dtype: int64
# FLAG_OWN_CAR
# N    202924
# Y    104587
# Name: count, dtype: int64
# FLAG_OWN_REALTY
# Y    213312
# N     94199
# Name: count, dtype: int64
# NAME_TYPE_SUITE_x
# Unaccompanied      248526
# Family              40149
# Spouse, partner     11370
# Children             3267
# Other_B              1770
# Other_A               866
# Group of people       271
# Name: count, dtype: int64
# NAME_INCOME_TYPE
# Working                 158774
# Commercial associate     71617
# Pensioner                55362
# State servant            21703
# Unemployed                  22
# Student                     18
# Businessman                 10
# Maternity leave              5
# Name: count, dtype: int64
# NAME_EDUCATION_TYPE
# Secondary / secondary special    218391
# Higher education                  74863
# Incomplete higher                 10277
# Lower secondary                    3816
# Academic degree                     164
# Name: count, dtype: int64
# NAME_FAMILY_STATUS
# Married                 196432
# Single / not married     45444
# Civil marriage           29775
# Separated                19770
# Widow                    16088
# Unknown                      2
# Name: count, dtype: int64
# NAME_HOUSING_TYPE
# House / apartment      272868
# With parents            14840
# Municipal apartment     11183
# Rented apartment         4881
# Office apartment         2617
# Co-op apartment          1122
# Name: count, dtype: int64
# OCCUPATION_TYPE
# Laborers                 55186
# Sales staff              32102
# Core staff               27570
# Managers                 21371
# Drivers                  18603
# High skill tech staff    11380
# Accountants               9813
# Medicine staff            8537
# Security staff            6721
# Cooking staff             5946
# Cleaning staff            4653
# Private service staff     2652
# Low-skill Laborers        2093
# Waiters/barmen staff      1348
# Secretaries               1305
# Realty agents              751
# HR staff                   563
# IT staff                   526
# Name: count, dtype: int64
# WEEKDAY_APPR_PROCESS_START_x
# TUESDAY      53901
# WEDNESDAY    51934
# MONDAY       50714
# THURSDAY     50591
# FRIDAY       50338
# SATURDAY     33852
# SUNDAY       16181
# Name: count, dtype: int64
# ORGANIZATION_TYPE
# Business Entity Type 3    67992
# XNA                       55374
# Self-employed             38412
# Other                     16683
# Medicine                  11193
# Business Entity Type 2    10553
# Government                10404
# School                     8893
# Trade: type 7              7831
# Kindergarten               6880
# Construction               6721
# Business Entity Type 1     5984
# Transport: type 4          5398
# Trade: type 3              3492
# Industry: type 9           3368
# Industry: type 3           3278
# Security                   3247
# Housing                    2958
# Industry: type 11          2704
# Military                   2634
# Bank                       2507
# Agriculture                2454
# Police                     2341
# Transport: type 2          2204
# Postal                     2157
# Security Ministries        1974
# Trade: type 2              1900
# Restaurant                 1811
# Services                   1575
# University                 1327
# Industry: type 7           1307
# Transport: type 3          1187
# Industry: type 1           1039
# Hotel                       966
# Electricity                 950
# Industry: type 4            877
# Trade: type 6               631
# Industry: type 5            599
# Insurance                   597
# Telecom                     577
# Emergency                   560
# Industry: type 2            458
# Advertising                 429
# Realtor                     396
# Culture                     379
# Industry: type 12           369
# Trade: type 1               348
# Mobile                      317
# Legal Services              305
# Cleaning                    260
# Transport: type 1           201
# Industry: type 6            112
# Industry: type 10           109
# Religion                     85
# Industry: type 13            67
# Trade: type 4                64
# Trade: type 5                49
# Industry: type 8             24
# Name: count, dtype: int64
# FONDKAPREMONT_MODE
# reg oper account         73830
# reg oper spec account    12080
# not specified             5687
# org spec account          5619
# Name: count, dtype: int64
# HOUSETYPE_MODE
# block of flats      150503
# specific housing      1499
# terraced house        1212
# Name: count, dtype: int64
# WALLSMATERIAL_MODE
# Panel           66040
# Stone, brick    64815
# Block            9253
# Wooden           5362
# Mixed            2296
# Monolithic       1779
# Others           1625
# Name: count, dtype: int64
# EMERGENCYSTATE_MODE
# No     159428
# Yes      2328
# Name: count, dtype: int64
# CREDIT_ACTIVE
# Closed      178030
# Active       84700
# Sold           758
# Bad debt         3
# Name: count, dtype: int64
# CREDIT_CURRENCY
# currency 1    263288
# currency 2       191
# currency 3        11
# currency 4         1
# Name: count, dtype: int64
# CREDIT_TYPE
# Consumer credit                           193529
# Credit card                                60980
# Car loan                                    4095
# Mortgage                                    3863
# Microloan                                    571
# Another type of loan                         207
# Loan for business development                186
# Loan for working capital replenishment        28
# Unknown type of loan                          27
# Real estate loan                               3
# Loan for the purchase of equipment             2
# Name: count, dtype: int64
# NAME_CONTRACT_TYPE_y
# Consumer loans     172562
# Cash loans          90069
# Revolving loans     28378
# XNA                    48
# Name: count, dtype: int64
# WEEKDAY_APPR_PROCESS_START_y
# SATURDAY     44971
# WEDNESDAY    42920
# FRIDAY       42738
# TUESDAY      42672
# MONDAY       42340
# THURSDAY     42288
# SUNDAY       33128
# Name: count, dtype: int64
# FLAG_LAST_APPL_PER_CONTRACT
# Y    290205
# N       852
# Name: count, dtype: int64
# NAME_CASH_LOAN_PURPOSE
# XAP                                 200988
# XNA                                  80319
# Repairs                               3230
# Other                                 2160
# Urgent needs                          1320
# Buying a used car                      386
# Everyday expenses                      346
# Medicine                               337
# Building a house or an annex           329
# Education                              223
# Journey                                185
# Purchase of electronic equipment       178
# Payments on other loans                169
# Wedding / gift / holiday               152
# Furniture                              147
# Car repairs                            136
# Buying a new car                       130
# Buying a home                          110
# Buying a holiday home / land            75
# Business development                    56
# Gasification / water supply             53
# Buying a garage                         14
# Hobby                                    6
# Money for a third person                 6
# Refusal to name the goal                 2
# Name: count, dtype: int64
# NAME_CONTRACT_STATUS_x
# Approved        219623
# Canceled         35064
# Refused          31948
# Unused offer      4422
# Name: count, dtype: int64
# NAME_PAYMENT_TYPE
# Cash through the bank                        199793
# XNA                                           89237
# Non-cash from your account                     1806
# Cashless from the account of the employer       221
# Name: count, dtype: int64
# CODE_REJECT_REASON
# XAP       254684
# HC         17017
# LIMIT       7350
# SCO         4880
# CLIENT      4422
# SCOFR       1575
# XNA          597
# VERIF        438
# SYSTEM        94
# Name: count, dtype: int64
# NAME_TYPE_SUITE_y
# Unaccompanied      82431
# Family             43158
# Spouse, partner    13821
# Children            6362
# Other_B             3672
# Other_A             1989
# Group of people      459
# Name: count, dtype: int64
# NAME_CLIENT_TYPE
# Repeater     158683
# New          102936
# Refreshed     29186
# XNA             252
# Name: count, dtype: int64
# NAME_GOODS_CATEGORY
# XNA                         119926
# Mobile                       51317
# Consumer Electronics         28761
# Computers                    25160
# Audio/Video                  23197
# Furniture                    13698
# Construction Materials        6402
# Clothing and Accessories      6334
# Photo / Cinema Equipment      5466
# Auto Accessories              1804
# Jewelry                       1509
# Homewares                     1436
# Medical Supplies              1337
# Vehicles                       921
# Sport and Leisure              758
# Gardening                      691
# Other                          550
# Medicine                       546
# Office Appliances              480
# Tourism                        465
# Direct Sales                   119
# Fitness                         80
# Education                       42
# Additional Service              27
# Weapon                          17
# Insurance                       13
# Animals                          1
# Name: count, dtype: int64
# NAME_PORTFOLIO
# POS      166472
# Cash      59070
# XNA       42756
# Cards     22655
# Cars        104
# Name: count, dtype: int64
# NAME_PRODUCT_TYPE
# XNA        209332
# x-sell      58608
# walk-in     23117
# Name: count, dtype: int64
# CHANNEL_TYPE
# Country-wide                  108979
# Credit and cash offices        84925
# Stone                          51745
# Regional / Local               26600
# Contact center                  8983
# AP+ (Cash loan)                 8596
# Channel of corporate sales      1119
# Car dealer                       110
# Name: count, dtype: int64
# NAME_SELLER_INDUSTRY
# XNA                     103941
# Consumer electronics     89326
# Connectivity             61460
# Furniture                14636
# Construction              7702
# Clothing                  6362
# Industry                  5213
# Auto technology           1361
# Jewelry                    657
# MLM partners               283
# Tourism                    116
# Name: count, dtype: int64
# NAME_YIELD_GROUP
# middle        74392
# high          69586
# XNA           65411
# low_normal    61510
# low_action    20158
# Name: count, dtype: int64
# PRODUCT_COMBINATION
# POS household with interest       61017
# POS mobile with interest          49738
# Cash                              30999
# POS industry with interest        25652
# POS household without interest    19658
# Cash X-Sell: middle               17787
# Card Street                       17146
# Cash X-Sell: low                  15054
# Card X-Sell                       11232
# Cash Street: high                  9266
# Cash X-Sell: high                  7932
# POS other with interest            6266
# POS mobile without interest        6178
# Cash Street: middle                5005
# Cash Street: low                   4026
# POS industry without interest      3314
# POS others without interest         739
# Name: count, dtype: int64
# NAME_CONTRACT_STATUS_y
# Active                   264048
# Completed                 22310
# Signed                     2728
# Returned to the store       185
# Approved                    152
# Demand                       20
# Canceled                      1
# Name: count, dtype: int64
# NAME_CONTRACT_STATUS
# Active           83337
# Completed         3188
# Signed             368
# Sent proposal        7
# Demand               5
# Name: count, dtype: int64

# %%
df_num = application_train.select_dtypes(include='number')
df_num
# Out:
#          SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0            100002       1             0          202500.0      406597.5
# 1            100003       0             0          270000.0     1293502.5
# 2            100004       0             0           67500.0      135000.0
# 3            100006       0             0          135000.0      312682.5
# 9            100007       0             0          121500.0      513000.0
# ...             ...     ...           ...               ...           ...
# 3448566      456251       0             0          157500.0      254700.0
# 3448567      456252       0             0           72000.0      269550.0
# 3448568      456253       0             0          153000.0      677664.0
# 3448569      456254       1             0          171000.0      370107.0
# 3448570      456255       0             0          157500.0      675000.0
#
#          AMT_ANNUITY_x  AMT_GOODS_PRICE_x  REGION_POPULATION_RELATIVE  \
# 0              24700.5           351000.0                    0.018801
# 1              35698.5          1129500.0                    0.003541
# 2               6750.0           135000.0                    0.010032
# 3              29686.5           297000.0                    0.008019
# 9              21865.5           513000.0                    0.028663
# ...                ...                ...                         ...
# 3448566        27558.0           225000.0                    0.032561
# 3448567        12001.5           225000.0                    0.025164
# 3448568        29979.0           585000.0                    0.005002
# 3448569        20205.0           319500.0                    0.005313
# 3448570        49117.5           675000.0                    0.046220
#
#          DAYS_BIRTH  DAYS_EMPLOYED  ...  AMT_RECEIVABLE_PRINCIPAL  \
# 0             -9461           -637  ...                       NaN
# 1            -16765          -1188  ...                       NaN
# 2            -19046           -225  ...                       NaN
# 3            -19005          -3039  ...                       0.0
# 9            -19932          -3038  ...                       NaN
# ...             ...            ...  ...                       ...
# 3448566       -9327           -236  ...                       NaN
# 3448567      -20775         365243  ...                       NaN
# 3448568      -14966          -7921  ...                       NaN
# 3448569      -11961          -4786  ...                       NaN
# 3448570      -16856          -1262  ...                       NaN
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 0                  NaN                   NaN                       NaN
# 1                  NaN                   NaN                       NaN
# 2                  NaN                   NaN                       NaN
# 3                  0.0                   0.0                       NaN
# 9                  NaN                   NaN                       NaN
# ...                ...                   ...                       ...
# 3448566            NaN                   NaN                       NaN
# 3448567            NaN                   NaN                       NaN
# 3448568            NaN                   NaN                       NaN
# 3448569            NaN                   NaN                       NaN
# 3448570            NaN                   NaN                       NaN
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         0.0                         NaN
# 9                         NaN                         NaN
# ...                       ...                         ...
# 3448566                   NaN                         NaN
# 3448567                   NaN                         NaN
# 3448568                   NaN                         NaN
# 3448569                   NaN                         NaN
# 3448570                   NaN                         NaN
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  SK_DPD_y  \
# 0                             NaN                        NaN       NaN
# 1                             NaN                        NaN       NaN
# 2                             NaN                        NaN       NaN
# 3                             NaN                        0.0       0.0
# 9                             NaN                        NaN       NaN
# ...                           ...                        ...       ...
# 3448566                       NaN                        NaN       NaN
# 3448567                       NaN                        NaN       NaN
# 3448568                       NaN                        NaN       NaN
# 3448569                       NaN                        NaN       NaN
# 3448570                       NaN                        NaN       NaN
#
#          SK_DPD_DEF_y
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 0.0
# 9                 NaN
# ...               ...
# 3448566           NaN
# 3448567           NaN
# 3448568           NaN
# 3448569           NaN
# 3448570           NaN
#
# [307511 rows x 166 columns]

# %%
# df_num = df_num.dropna()
# df_num

# %%
df_num = df_num.drop_duplicates(subset=["SK_ID_CURR"])
df_num
# Out:
#          SK_ID_CURR  TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0            100002       1             0          202500.0      406597.5
# 1            100003       0             0          270000.0     1293502.5
# 2            100004       0             0           67500.0      135000.0
# 3            100006       0             0          135000.0      312682.5
# 9            100007       0             0          121500.0      513000.0
# ...             ...     ...           ...               ...           ...
# 3448566      456251       0             0          157500.0      254700.0
# 3448567      456252       0             0           72000.0      269550.0
# 3448568      456253       0             0          153000.0      677664.0
# 3448569      456254       1             0          171000.0      370107.0
# 3448570      456255       0             0          157500.0      675000.0
#
#          AMT_ANNUITY_x  AMT_GOODS_PRICE_x  REGION_POPULATION_RELATIVE  \
# 0              24700.5           351000.0                    0.018801
# 1              35698.5          1129500.0                    0.003541
# 2               6750.0           135000.0                    0.010032
# 3              29686.5           297000.0                    0.008019
# 9              21865.5           513000.0                    0.028663
# ...                ...                ...                         ...
# 3448566        27558.0           225000.0                    0.032561
# 3448567        12001.5           225000.0                    0.025164
# 3448568        29979.0           585000.0                    0.005002
# 3448569        20205.0           319500.0                    0.005313
# 3448570        49117.5           675000.0                    0.046220
#
#          DAYS_BIRTH  DAYS_EMPLOYED  ...  AMT_RECEIVABLE_PRINCIPAL  \
# 0             -9461           -637  ...                       NaN
# 1            -16765          -1188  ...                       NaN
# 2            -19046           -225  ...                       NaN
# 3            -19005          -3039  ...                       0.0
# 9            -19932          -3038  ...                       NaN
# ...             ...            ...  ...                       ...
# 3448566       -9327           -236  ...                       NaN
# 3448567      -20775         365243  ...                       NaN
# 3448568      -14966          -7921  ...                       NaN
# 3448569      -11961          -4786  ...                       NaN
# 3448570      -16856          -1262  ...                       NaN
#
#          AMT_RECIVABLE  AMT_TOTAL_RECEIVABLE  CNT_DRAWINGS_ATM_CURRENT  \
# 0                  NaN                   NaN                       NaN
# 1                  NaN                   NaN                       NaN
# 2                  NaN                   NaN                       NaN
# 3                  0.0                   0.0                       NaN
# 9                  NaN                   NaN                       NaN
# ...                ...                   ...                       ...
# 3448566            NaN                   NaN                       NaN
# 3448567            NaN                   NaN                       NaN
# 3448568            NaN                   NaN                       NaN
# 3448569            NaN                   NaN                       NaN
# 3448570            NaN                   NaN                       NaN
#
#          CNT_DRAWINGS_CURRENT  CNT_DRAWINGS_OTHER_CURRENT  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         0.0                         NaN
# 9                         NaN                         NaN
# ...                       ...                         ...
# 3448566                   NaN                         NaN
# 3448567                   NaN                         NaN
# 3448568                   NaN                         NaN
# 3448569                   NaN                         NaN
# 3448570                   NaN                         NaN
#
#          CNT_DRAWINGS_POS_CURRENT  CNT_INSTALMENT_MATURE_CUM  SK_DPD_y  \
# 0                             NaN                        NaN       NaN
# 1                             NaN                        NaN       NaN
# 2                             NaN                        NaN       NaN
# 3                             NaN                        0.0       0.0
# 9                             NaN                        NaN       NaN
# ...                           ...                        ...       ...
# 3448566                       NaN                        NaN       NaN
# 3448567                       NaN                        NaN       NaN
# 3448568                       NaN                        NaN       NaN
# 3448569                       NaN                        NaN       NaN
# 3448570                       NaN                        NaN       NaN
#
#          SK_DPD_DEF_y
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 0.0
# 9                 NaN
# ...               ...
# 3448566           NaN
# 3448567           NaN
# 3448568           NaN
# 3448569           NaN
# 3448570           NaN
#
# [307511 rows x 166 columns]

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(df_num.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df_num.corr().where(lambda x: abs(x)>0.5), mask=mask, square=True)
# Out:
# <Axes: >

# %%
# split data
X = df_num.drop(columns=["TARGET", "SK_ID_CURR"])
y = df_num["TARGET"].copy()

# %%
# Training split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)

num_cols = X.columns.to_list()

# Create Transformers
zero_imputer = SimpleImputer(strategy="constant", fill_value=0)
# scaler = StandardScaler()

# Create tuples
impute_tuple = ("imputation", zero_imputer, num_cols)
# scaler_tuple = ("scaling", scaler, num_cols)


# Create ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[impute_tuple], remainder="passthrough",
    verbose_feature_names_out=True)

# Test preprocessor
preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)
X_val_proc = preprocessor.transform(X_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 24
#      22 X_train_proc = preprocessor.transform(X_train)
#      23 X_test_proc = preprocessor.transform(X_test)
# ---> 24 X_val_proc = preprocessor.transform(X_val)
#
# NameError: name 'X_val' is not defined

# %%
logreg_balanced = LogisticRegression(max_iter=1000, class_weight="balanced")

logreg_balanced_pipe = make_pipeline(StandardScaler(), logreg_balanced)

logreg_balanced_pipe.fit(X_train_proc, y_train)

# balanced_results = eval_classification(logreg_balanced_pipe, X_train_proc, y_train, X_test_proc, y_test,
#                               model_name="Logistic Regression Balanced Class Weights")

# balanced_results

print("Train")
print(classification_report(y_train, train_pred))
print("Test")
print(classification_report(y_test, test_pred))

# %%
# from sklearn.model_selection import GridSearchCV

# knn = KNeighborsClassifier()
# param_space = {'n_neighbors': range(3,8)}
# knn_gs = GridSearchCV(knn, param_space)
# knn_gs.fit(X_train_proc, y_train)
# best_knn = knn_gs.best_estimator_
# best_knn
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
knn_pipe = Pipeline([("scaler", StandardScaler()), ("knn", best_knn)])

knn_pipe.fit(X_train_proc, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('knn', KNeighborsClassifier(n_neighbors=6))])

# %%
zero_imputer.fit(X)

zero_X = zero_imputer.transform(X)
knn_pipe2 = Pipeline([("scaler", StandardScaler()), 
                      ("knn", KNeighborsClassifier(n_neighbors=6))])

knn_pipe2.fit(zero_X, y) 

zero_X_cols = zero_X.columns.to_list()

# %%
test_data_file = "application_test.csv"
test_data = pd.read_csv(local_prepend + input_path + test_data_file)

test_data = pd.merge(test_data, bureau, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, previous_application, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, POS_CASH_balance, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, credit_card_balance, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])

ids = test_data.pop("SK_ID_CURR")

test_data = test_data[zero_X_cols]

zero_test = zero_imputer.transform(test_data)

preds = knn_pipe2.predict_proba(zero_test)[:,1]

output = pd.DataFrame({"SK_ID_CURR": ids,
                       "TARGET": preds})

# %%
output
# Out:
#         SK_ID_CURR    TARGET
# 0           100001  0.166667
# 1           100005  0.000000
# 2           100013  0.000000
# 98          100028  0.166667
# 147         100038  0.500000
# ...            ...       ...
# 644422      456221  0.166667
# 644423      456222  0.000000
# 644424      456223  0.166667
# 644425      456224  0.000000
# 644426      456250  0.333333
#
# [48744 rows x 2 columns]

# %%
sample_submission_file = "sample_submission.csv"
sample_submission_df = pd.read_csv(local_prepend + input_path + sample_submission_file)
sample_submission_df["TARGET"] = preds
sample_submission_df.to_csv("00f_more_merges.csv", index=False)
sample_submission_df.head()
# Out:
#    SK_ID_CURR    TARGET
# 0      100001  0.166667
# 1      100005  0.000000
# 2      100013  0.000000
# 3      100028  0.166667
# 4      100038  0.500000

# %%
# # create a logistic regression
# log_reg = LogisticRegression(max_iter=100000, random_state=42)
# log_reg.fit(X_train_proc, y_train)
# log_reg.predict_proba(X_test_proc)[:,0]

# %%
eval_classification(best_knn, X_train_proc, y_train, X_test_proc, y_test, model_name="best knn", results_frame=None,
                        pos_label=1, average="binary")
# Out:
# Train Evaluation
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    211999
#            1       0.00      0.00      0.00     18634
#
#     accuracy                           0.92    230633
#    macro avg       0.46      0.50      0.48    230633
# weighted avg       0.84      0.92      0.88    230633
#
# Test Evaluation
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     70687
#            1       0.00      0.00      0.00      6191
#
#     accuracy                           0.92     76878
#    macro avg       0.46      0.50      0.48     76878
# weighted avg       0.85      0.92      0.88     76878
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/bharat/Documents/GitHub/kaggle/.conda/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#           train_acc  test_acc  train_prec  test_prec  train_recall  \
# best knn   0.919205   0.91947         0.0        0.0           0.0
#
#           test_recall  train_f1  test_f1
# best knn          0.0       0.0      0.0

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

# %%
y_train.value_counts()
# Out:
# TARGET
# 0    211999
# 1     18634
# Name: count, dtype: int64
