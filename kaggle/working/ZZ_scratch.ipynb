# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, classification_report, 
                             ConfusionMatrixDisplay)

from sklearn import set_config
set_config(transform_output="pandas")

from category_encoders import HashingEncoder

import sqlite3

from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, ConfusionMatrixDisplay

from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import roc_auc_score, RocCurveDisplay, PrecisionRecallDisplay

import joblib

# %%
# utilizing test data results to pick classifiers, selecting by ROC AUC score, then recall, then f1 score

estimators = [('hgb', hgb), # #1: ROC AUC, f1 #2: recall
              ('xgb', xgb), # #2: ROC AUC('gnb', gnb), # #1: recall
              ('rf_cv', rf), # #3: ROC AUC, #2 f1
              ('gnb', gnb), # #1: recall
              ('logreg_cv', logreg_cv), # #3: recall, #4: f1 (untuned was #3 but picking this instead)
              ('svc', LinearSVC(random_state=42, class_weight="balanced").fit(X_train, y_train))] # adding for variety

stacked_clf = StackingClassifier(estimators=estimators, n_jobs=-1, cv="prefit").fit(X_train, y_train)

stacked_clf_results = eval_classification(stacked_clf, X_train, y_train, X_test, y_test, 
                                          model_name="Stacked Classifier", results_frame=bnb_results)
# Out:
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#                     Train Evaluation                                       Test Evaluation
#               precision    recall  f1-score   support                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226132             0       0.92      1.00      0.96     56554
#            1       1.00      1.00      1.00     19876             1       0.48      0.02      0.04      4949
#
#     accuracy                           1.00    246008      accuracy                           0.92     61503
#    macro avg       1.00      1.00      1.00    246008     macro avg       0.70      0.51      0.50     61503
# weighted avg       1.00      1.00      1.00    246008  weighted avg       0.89      0.92      0.88     61503
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
stacked_clf_results.style.background_gradient()
# Out:
# <style type="text/css">
# #T_cfab9_row0_col0, #T_cfab9_row1_col0, #T_cfab9_row3_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col1, #T_cfab9_row1_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col2, #T_cfab9_row1_col2, #T_cfab9_row3_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_cfab9_row0_col3, #T_cfab9_row1_col3, #T_cfab9_row4_col3, #T_cfab9_row7_col6 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_cfab9_row0_col4, #T_cfab9_row1_col4, #T_cfab9_row3_col4, #T_cfab9_row4_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col5, #T_cfab9_row1_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col6, #T_cfab9_row1_col6, #T_cfab9_row3_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_cfab9_row0_col7, #T_cfab9_row1_col7, #T_cfab9_row8_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col8, #T_cfab9_row1_col8 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_cfab9_row0_col9, #T_cfab9_row1_col9 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_cfab9_row2_col0, #T_cfab9_row2_col2, #T_cfab9_row2_col4, #T_cfab9_row2_col6, #T_cfab9_row2_col8, #T_cfab9_row5_col0, #T_cfab9_row5_col1, #T_cfab9_row5_col2, #T_cfab9_row5_col3, #T_cfab9_row5_col4, #T_cfab9_row5_col6, #T_cfab9_row5_col8, #T_cfab9_row7_col7, #T_cfab9_row7_col9, #T_cfab9_row8_col1, #T_cfab9_row10_col5, #T_cfab9_row12_col0, #T_cfab9_row12_col1, #T_cfab9_row12_col2, #T_cfab9_row12_col4, #T_cfab9_row12_col6, #T_cfab9_row12_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_cfab9_row2_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_cfab9_row2_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_cfab9_row2_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_cfab9_row2_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_cfab9_row2_col9, #T_cfab9_row4_col2, #T_cfab9_row6_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_cfab9_row3_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_cfab9_row3_col3, #T_cfab9_row9_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_cfab9_row3_col5 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_cfab9_row3_col7 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_cfab9_row3_col8 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_cfab9_row3_col9 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col4 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col6, #T_cfab9_row12_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_cfab9_row4_col7, #T_cfab9_row9_col9 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_cfab9_row4_col9 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_cfab9_row5_col5, #T_cfab9_row5_col7, #T_cfab9_row8_col4, #T_cfab9_row10_col0, #T_cfab9_row10_col1, #T_cfab9_row10_col2, #T_cfab9_row10_col3, #T_cfab9_row10_col6, #T_cfab9_row10_col8, #T_cfab9_row10_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_cfab9_row5_col9, #T_cfab9_row12_col9 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_cfab9_row6_col4, #T_cfab9_row11_col9 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col5 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col6 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_cfab9_row6_col7 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col8 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_cfab9_row6_col9 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_cfab9_row7_col0, #T_cfab9_row7_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_cfab9_row7_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_cfab9_row7_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_cfab9_row7_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_cfab9_row7_col4, #T_cfab9_row9_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_cfab9_row7_col8 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_cfab9_row8_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_cfab9_row8_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_cfab9_row8_col5, #T_cfab9_row8_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_cfab9_row8_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_cfab9_row8_col8 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_cfab9_row8_col9, #T_cfab9_row9_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col3 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col7 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_cfab9_row9_col8 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_cfab9_row10_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_cfab9_row10_col7 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_cfab9_row11_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_cfab9_row11_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_cfab9_row11_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_cfab9_row11_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_cfab9_row11_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_cfab9_row11_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_cfab9_row11_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_cfab9_row11_col7 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_cfab9_row11_col8 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_cfab9_row12_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_cfab9_row12_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# </style>
# <table id="T_cfab9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfab9_level0_col0" class="col_heading level0 col0" >train_acc</th>
#       <th id="T_cfab9_level0_col1" class="col_heading level0 col1" >test_acc</th>
#       <th id="T_cfab9_level0_col2" class="col_heading level0 col2" >train_prec</th>
#       <th id="T_cfab9_level0_col3" class="col_heading level0 col3" >test_prec</th>
#       <th id="T_cfab9_level0_col4" class="col_heading level0 col4" >train_recall</th>
#       <th id="T_cfab9_level0_col5" class="col_heading level0 col5" >test_recall</th>
#       <th id="T_cfab9_level0_col6" class="col_heading level0 col6" >train_f1</th>
#       <th id="T_cfab9_level0_col7" class="col_heading level0 col7" >test_f1</th>
#       <th id="T_cfab9_level0_col8" class="col_heading level0 col8" >train_auc</th>
#       <th id="T_cfab9_level0_col9" class="col_heading level0 col9" >test_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfab9_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_cfab9_row0_col0" class="data row0 col0" >0.688201</td>
#       <td id="T_cfab9_row0_col1" class="data row0 col1" >0.685284</td>
#       <td id="T_cfab9_row0_col2" class="data row0 col2" >0.160394</td>
#       <td id="T_cfab9_row0_col3" class="data row0 col3" >0.157677</td>
#       <td id="T_cfab9_row0_col4" class="data row0 col4" >0.675186</td>
#       <td id="T_cfab9_row0_col5" class="data row0 col5" >0.670438</td>
#       <td id="T_cfab9_row0_col6" class="data row0 col6" >0.259211</td>
#       <td id="T_cfab9_row0_col7" class="data row0 col7" >0.255309</td>
#       <td id="T_cfab9_row0_col8" class="data row0 col8" >0.745930</td>
#       <td id="T_cfab9_row0_col9" class="data row0 col9" >0.743762</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# # Calibration

# %%
calibrated_clf = CalibratedClassifierCV(FrozenEstimator(stacked_clf), cv=10, n_jobs=-1).fit(X_test, y_test)

calibrated_clf_results = eval_classification(calibrated_clf, X_train, y_train, X_test, y_test,
                                  model_name="Calibrated Classifier", results_frame=stacked_clf_results)
# Out:
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
#                     Train Evaluation                                       Test Evaluation
#               precision    recall  f1-score   support                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    226132             0       0.92      1.00      0.96     56554
#            1       1.00      1.00      1.00     19876             1       0.44      0.04      0.08      4949
#
#     accuracy                           1.00    246008      accuracy                           0.92     61503
#    macro avg       1.00      1.00      1.00    246008     macro avg       0.68      0.52      0.52     61503
# weighted avg       1.00      1.00      1.00    246008  weighted avg       0.88      0.92      0.89     61503
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
calibrated_clf_results.style.background_gradient()
# Out:
# <style type="text/css">
# #T_05e38_row0_col0, #T_05e38_row1_col0, #T_05e38_row3_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col1, #T_05e38_row1_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col2, #T_05e38_row1_col2, #T_05e38_row3_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_05e38_row0_col3, #T_05e38_row1_col3, #T_05e38_row4_col3, #T_05e38_row7_col6 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_05e38_row0_col4, #T_05e38_row1_col4, #T_05e38_row3_col4, #T_05e38_row4_col5 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col5, #T_05e38_row1_col5 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col6, #T_05e38_row1_col6, #T_05e38_row3_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_05e38_row0_col7, #T_05e38_row1_col7, #T_05e38_row8_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col8, #T_05e38_row1_col8 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_05e38_row0_col9, #T_05e38_row1_col9 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_05e38_row2_col0, #T_05e38_row2_col2, #T_05e38_row2_col4, #T_05e38_row2_col6, #T_05e38_row2_col8, #T_05e38_row5_col0, #T_05e38_row5_col1, #T_05e38_row5_col2, #T_05e38_row5_col3, #T_05e38_row5_col4, #T_05e38_row5_col6, #T_05e38_row5_col8, #T_05e38_row7_col7, #T_05e38_row7_col9, #T_05e38_row8_col1, #T_05e38_row10_col5, #T_05e38_row12_col0, #T_05e38_row12_col1, #T_05e38_row12_col2, #T_05e38_row12_col4, #T_05e38_row12_col6, #T_05e38_row12_col8, #T_05e38_row13_col0, #T_05e38_row13_col1, #T_05e38_row13_col2, #T_05e38_row13_col4, #T_05e38_row13_col6, #T_05e38_row13_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_05e38_row2_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_05e38_row2_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_05e38_row2_col5 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_05e38_row2_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_05e38_row2_col9, #T_05e38_row4_col2, #T_05e38_row6_col2 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_05e38_row3_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_05e38_row3_col3, #T_05e38_row9_col5 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_05e38_row3_col5 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_05e38_row3_col7 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_05e38_row3_col8 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_05e38_row3_col9 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col4 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col6, #T_05e38_row12_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_05e38_row4_col7, #T_05e38_row9_col9 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col8 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_05e38_row4_col9 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_05e38_row5_col5, #T_05e38_row5_col7, #T_05e38_row8_col4, #T_05e38_row10_col0, #T_05e38_row10_col1, #T_05e38_row10_col2, #T_05e38_row10_col3, #T_05e38_row10_col6, #T_05e38_row10_col8, #T_05e38_row10_col9 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_05e38_row5_col9, #T_05e38_row12_col9, #T_05e38_row13_col9 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col0 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_05e38_row6_col4, #T_05e38_row11_col9 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col5 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col6 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_05e38_row6_col7 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col8 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_05e38_row6_col9 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_05e38_row7_col0, #T_05e38_row7_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_05e38_row7_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_05e38_row7_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_05e38_row7_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_05e38_row7_col4, #T_05e38_row9_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_05e38_row7_col8 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_05e38_row8_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_05e38_row8_col3 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_05e38_row8_col5, #T_05e38_row8_col6 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_05e38_row8_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_05e38_row8_col8 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_05e38_row8_col9, #T_05e38_row9_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col3 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col7 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_05e38_row9_col8 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_05e38_row10_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_05e38_row10_col7 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_05e38_row11_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_05e38_row11_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_05e38_row11_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_05e38_row11_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_05e38_row11_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_05e38_row11_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_05e38_row11_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_05e38_row11_col7 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_05e38_row11_col8 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_05e38_row12_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_05e38_row12_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_05e38_row13_col3 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_05e38_row13_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_05e38_row13_col7 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# </style>
# <table id="T_05e38">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05e38_level0_col0" class="col_heading level0 col0" >train_acc</th>
#       <th id="T_05e38_level0_col1" class="col_heading level0 col1" >test_acc</th>
#       <th id="T_05e38_level0_col2" class="col_heading level0 col2" >train_prec</th>
#       <th id="T_05e38_level0_col3" class="col_heading level0 col3" >test_prec</th>
#       <th id="T_05e38_level0_col4" class="col_heading level0 col4" >train_recall</th>
#       <th id="T_05e38_level0_col5" class="col_heading level0 col5" >test_recall</th>
#       <th id="T_05e38_level0_col6" class="col_heading level0 col6" >train_f1</th>
#       <th id="T_05e38_level0_col7" class="col_heading level0 col7" >test_f1</th>
#       <th id="T_05e38_level0_col8" class="col_heading level0 col8" >train_auc</th>
#       <th id="T_05e38_level0_col9" class="col_heading level0 col9" >test_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05e38_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_05e38_row0_col0" class="data row0 col0" >0.688201</td>
#       <td id="T_05e38_row0_col1" class="data row0 col1" >0.685284</td>
#       <td id="T_05e38_row0_col2" class="data row0 col2" >0.160394</td>
#       <td id="T_05e38_row0_col3" class="data row0 col3" >0.157677</td>
#       <td id="T_05e38_row0_col4" class="data row0 col4" >0.675186</td>
#       <td id="T_05e38_ro

# %%
RocCurveDisplay.from_estimator(hgb, X_test, y_test)

# %% [markdown]
# # Calibration

# %%
calibrated_clf = CalibratedClassifierCV(FrozenEstimator(stacked_clf), n_jobs=-1).fit(X_test, y_test)

calibrated_clf_results = eval_classification(calibrated_clf, X_train, y_train, X_test, y_test,
                                  model_name="Calibrated Classifier", results_frame=stacked_clf_results)
# Out:
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
#                     Train Evaluation                                       Test Evaluation
#               precision    recall  f1-score   support                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    197845             0       0.92      1.00      0.96     56514
#            1       0.81      0.03      0.07     17412             1       0.55      0.02      0.04      4988
#
#     accuracy                           0.92    215257      accuracy                           0.92     61502
#    macro avg       0.87      0.52      0.51    215257     macro avg       0.74      0.51      0.50     61502
# weighted avg       0.91      0.92      0.89    215257  weighted avg       0.89      0.92      0.88     61502
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegressionCV was fitted without feature names
#   warnings.warn(

# %%
calibrated_clf_results.style.background_gradient()
# Out:
# <style type="text/css">
# #T_77d9f_row0_col0, #T_77d9f_row1_col0, #T_77d9f_row11_col9 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col1, #T_77d9f_row1_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col2, #T_77d9f_row1_col2, #T_77d9f_row2_col9, #T_77d9f_row3_col2, #T_77d9f_row4_col2, #T_77d9f_row6_col7 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_77d9f_row0_col3, #T_77d9f_row1_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_77d9f_row0_col4, #T_77d9f_row1_col4 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col5, #T_77d9f_row1_col5 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col6, #T_77d9f_row1_col6 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_77d9f_row0_col7, #T_77d9f_row1_col7, #T_77d9f_row13_col0 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col8, #T_77d9f_row1_col8 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_77d9f_row0_col9, #T_77d9f_row1_col9 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_77d9f_row2_col0, #T_77d9f_row2_col2, #T_77d9f_row2_col4, #T_77d9f_row2_col6, #T_77d9f_row2_col8, #T_77d9f_row5_col0, #T_77d9f_row5_col1, #T_77d9f_row5_col2, #T_77d9f_row5_col4, #T_77d9f_row5_col6, #T_77d9f_row5_col8, #T_77d9f_row6_col0, #T_77d9f_row6_col1, #T_77d9f_row6_col2, #T_77d9f_row6_col4, #T_77d9f_row6_col6, #T_77d9f_row6_col8, #T_77d9f_row8_col1, #T_77d9f_row10_col5, #T_77d9f_row12_col7, #T_77d9f_row12_col9, #T_77d9f_row13_col1, #T_77d9f_row13_col3, #T_77d9f_row13_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_77d9f_row2_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_77d9f_row2_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_77d9f_row2_col5 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_77d9f_row2_col7 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col0, #T_77d9f_row4_col0 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col1, #T_77d9f_row4_col1, #T_77d9f_row8_col8 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col3, #T_77d9f_row4_col3, #T_77d9f_row9_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_77d9f_row3_col4, #T_77d9f_row4_col4 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col5, #T_77d9f_row4_col5, #T_77d9f_row7_col8 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col6, #T_77d9f_row4_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_77d9f_row3_col7, #T_77d9f_row4_col7 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_77d9f_row3_col8 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_77d9f_row3_col9 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_77d9f_row4_col8 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_77d9f_row4_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_77d9f_row5_col3 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_77d9f_row5_col5, #T_77d9f_row5_col7, #T_77d9f_row10_col0, #T_77d9f_row10_col1, #T_77d9f_row10_col2, #T_77d9f_row10_col3, #T_77d9f_row10_col8, #T_77d9f_row10_col9, #T_77d9f_row13_col4, #T_77d9f_row13_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_77d9f_row5_col9 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_77d9f_row6_col3, #T_77d9f_row8_col3, #T_77d9f_row13_col2 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_77d9f_row6_col5, #T_77d9f_row13_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_77d9f_row6_col9 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_77d9f_row7_col0, #T_77d9f_row12_col0, #T_77d9f_row12_col5 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_77d9f_row7_col1, #T_77d9f_row9_col7, #T_77d9f_row12_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_77d9f_row7_col2, #T_77d9f_row12_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_77d9f_row7_col3 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_77d9f_row7_col4 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_77d9f_row7_col5, #T_77d9f_row11_col7 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_77d9f_row7_col6 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_77d9f_row7_col7, #T_77d9f_row7_col9 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_77d9f_row8_col0 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_77d9f_row8_col2 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_77d9f_row8_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_77d9f_row8_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_77d9f_row8_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_77d9f_row8_col7 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_77d9f_row8_col9 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col1, #T_77d9f_row10_col4 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col2 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col4 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col6 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col8 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_77d9f_row9_col9 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_77d9f_row10_col6 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_77d9f_row10_col7 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_77d9f_row11_col0 {
#   background-color: #045e94;
#   color: #f1f1f1;
# }
# #T_77d9f_row11_col1 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_77d9f_row11_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_77d9f_row11_col3 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_77d9f_row11_col4 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_77d9f_row11_col5, #T_77d9f_row12_col3 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_77d9f_row11_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_77d9f_row11_col8 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_77d9f_row12_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_77d9f_row12_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_77d9f_row12_col8, #T_77d9f_row13_col8 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_77d9f_row13_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# </style>
# <table id="T_77d9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77d9f_level0_col0" class="col_heading level0 col0" >train_acc</th>
#       <th id="T_77d9f_level0_col1" class="col_heading level0 col1" >test_acc</th>
#       <th id="T_77d9f_level0_col2" class="col_heading level0 col2" >train_prec</th>
#       <th id="T_77d9f_level0_col3" class="col_heading level0 col3" >test_prec</th>
#       <th id="T_77d9f_level0_col4" class="col_heading level0 col4" >train_recall</th>
#       <th id="T_77d9f_level0_col5" class="col_heading level0 col5" >test_recall</th>
#       <th id="T_77d9f_level0_col6" class="col_heading level0 col6" >train_f1</th>
#       <th id="T_77d9f_level0_col7" class="col_heading level0 col7" >test_f1</th>
#       <th id="T_77d9f_level0_col8" class="col_heading level0 col8" >train_auc</th>
#       <th id="T_77d9f_level0_col9" class="col_heading level0 col9" >test_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77d9f_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#       <td id="T_77d9f_row0_col0" class="data row0 col0" >0.688647</td>
#       <td id="T_77d9f_row0_col1" class="data row0 col1" >0.686970</td>
#       <td id="T_77d9f_row0_col2" class="data row0 col2" >0.160524</td>
#       <td id="T_77d9f_row0_col3" class="data row0 col3" >0.158756</td>
#       <td id="T_77d9f_row0_col4" class="data row0 col4" >0.673616</td>
#       <td id="T_77d9f_row0_col5" class="data row0 col5" >0.665196</td>
#       <td id="T_77d9f_row0_col6" class="data row0 col6" >0.259265</td>
#       <td id="T_77d9f_row0_col7" class="data row0 col7" >0.256335</td>
#       <td id="T_77d9f_row0_col8" class="data row0 col8" >0.74

# %% [markdown]
# # iterate through different scikit-learn models

# %%
# -------- Cross validate model with Kfold stratified cross val ---------------

kfold = StratifiedKFold(n_splits=10)

# Modeling step Test differents algorithms
classifiers = ['AdaBoostClassifier',
                'BernoulliNB',
                'DummyClassifier']
results = []
for model in classifiers :
    results.append(cross_val_score(model, X_train, y = y_train, scoring = "accuracy", cv = kfold, n_jobs=4))

cv_means = []
cv_std = []
for cv_result in results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())

cv_res = pd.DataFrame({"CrossValMeans":cv_means,"CrossValerrors": cv_std,"Algorithm":["AdaBoostClassifier","BernoulliNB","DummyClassifier"]})`

# %%
# # First 	1	Enable GPU Runtime:
# 	•	Go to "Runtime" -> "Change runtime type".
# 	•	Select "GPU" as the hardware accelerator.
# 	•	Click "Save".

# %%
# # Install a specific CUDA version
# !apt-get --purge remove cuda nvidia* libnvidia-*
# !dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# !apt-get remove cuda-*
# !apt autoremove
# !apt-get update

# # Install CUDA 11.x
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget https://developer.download.nvidia.com/compute/cuda/11.8.0/local_installers/cuda-repo-ubuntu1804-11-8-local_11.8.0-520.61.05-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1804-11-8-local_11.8.0-520.61.05-1_amd64.deb
# !cp /var/cuda-repo-ubuntu1804-11-8-local/cuda-*-*.pub /tmp/cuda-*-*.pub
# !apt-key add /tmp/cuda-*-*.pub
# !apt-get update
# !apt-get -y install cuda

# %%
# !pip install cudf-cu11 --extra-index-url=https://pypi.nvidia.com

# %%
# import cudf  # this should work without any errors

# %%
# %load_ext cudf.pandas
# # Google Colab: Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU (musr first choose runtime that is a GPU)

# %%
# saving preprocessor for future use
to_save = {"preprocessor" : preprocessor,
           "porch_func" : porch_func}
filename = "preprocessor.joblib"

joblib.dump(to_save, filename)

# %%
# # Clone the entire repo.
# !git clone -l -s git://github.com/jakevdp/PythonDataScienceHandbook.git cloned-repo
# %cd cloned-repo
# !ls

# %%
# # Fetch a single <1MB file using the raw GitHub URL.
# !curl --remote-name \
#      -H 'Accept: application/vnd.github.v3.raw' \
#      --location https://api.github.com/repos/jakevdp/PythonDataScienceHandbook/contents/notebooks/data/california_cities.csv

# %%
# Run only once!
import os
print(os.getcwd())
os.chdir('../..')
print(os.getcwd())

# %%
local_prepend = "../.."
input_path = "/kaggle/input/home-credit-default-risk/"
# kaggle_notebook_input_path = "/kaggle/input/home-credit-default-risk/"

# con = sqlite3.connect(local_prepend + input_path + "home-credit-default-risk.sqlite") # connect to database
# pd.read_csv(local_prepend + input_path + "application_train.csv").to_sql("application_train", con, if_exists='append', index=False, index_label="SK_ID_CURR")

# application_train = pd.read_csv(local_prepend + input_path + "application_train.csv")

# bureau_balance = pd.read_csv(local_prepend + input_path + "bureau_balance.csv")
# bureau = pd.read_csv(local_prepend + input_path + "bureau.csv")
# credit_card_balance = pd.read_csv(local_prepend + input_path + "credit_card_balance.csv")
# installments_payments = pd.read_csv(local_prepend + input_path + "installments_payments.csv")
# POS_CASH_balance = pd.read_csv(local_prepend + input_path + "POS_CASH_balance.csv")
# previous_application = pd.read_csv(local_prepend + input_path + "previous_application.csv")

# Description of columns in provided datasets
HomeCredit_columns_description = pd.read_csv(local_prepend + input_path + "HomeCredit_columns_description.csv", encoding = "latin")

# # Test Data for later use
# application_test = pd.read_csv(local_prepend + input_path + "application_test.csv")

# %%
HomeCredit_columns_description

# %%
HomeCredit_columns_description[HomeCredit_columns_description["Table"] == "application_{train|test}.csv"][["Row", "Description"]]

# %%
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", None)

# %%
HomeCredit_columns_description[~HomeCredit_columns_description["Special"].isna()]

# %%
# dfs_to_merge = [bureau, previous_application, POS_CASH_balance, credit_card_balance]

# for df in dfs_to_merge:
#     application_train = pd.merge(application_train, df, how="inner", on="SK_ID_CURR")

# application_train.shape

# %%
application_train = pd.merge(application_train, bureau, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, previous_application, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, POS_CASH_balance, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])
application_train = pd.merge(application_train, credit_card_balance, how="left", on="SK_ID_CURR")
application_train = application_train.drop_duplicates(subset=["SK_ID_CURR"])

# %%
application_train.select_dtypes(include='object')

# %%
object_cols = application_train.select_dtypes(include='object').columns.to_list()

for col in object_cols:
    print(application_train[col].value_counts())

# %%
df_num = application_train.select_dtypes(include='number')
df_num

# %%
# df_num = df_num.dropna()
# df_num

# %%
df_num = df_num.drop_duplicates(subset=["SK_ID_CURR"])
df_num

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(df_num.corr(), dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df_num.corr().where(lambda x: abs(x)>0.5), mask=mask, square=True)

# %%
# split data
X = df_num.drop(columns=["TARGET", "SK_ID_CURR"])
y = df_num["TARGET"].copy()

# %%
# Training split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)

num_cols = X.columns.to_list()

# Create Transformers
zero_imputer = SimpleImputer(strategy="constant", fill_value=0)
# scaler = StandardScaler()

# Create tuples
impute_tuple = ("imputation", zero_imputer, num_cols)
# scaler_tuple = ("scaling", scaler, num_cols)


# Create ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[impute_tuple], remainder="passthrough",
    verbose_feature_names_out=True)

# Test preprocessor
preprocessor.fit(X_train)
X_train_proc = preprocessor.transform(X_train)
X_test_proc = preprocessor.transform(X_test)
X_val_proc = preprocessor.transform(X_val)

# %%
logreg_balanced = LogisticRegression(max_iter=1000, class_weight="balanced")

logreg_balanced_pipe = make_pipeline(StandardScaler(), logreg_balanced)

logreg_balanced_pipe.fit(X_train_proc, y_train)

# balanced_results = eval_classification(logreg_balanced_pipe, X_train_proc, y_train, X_test_proc, y_test,
#                               model_name="Logistic Regression Balanced Class Weights")

# balanced_results

print("Train")
print(classification_report(y_train, train_pred))
print("Test")
print(classification_report(y_test, test_pred))

# %%
# from sklearn.model_selection import GridSearchCV

# knn = KNeighborsClassifier()
# param_space = {'n_neighbors': range(3,8)}
# knn_gs = GridSearchCV(knn, param_space)
# knn_gs.fit(X_train_proc, y_train)
# best_knn = knn_gs.best_estimator_
# best_knn

# %%
knn_pipe = Pipeline([("scaler", StandardScaler()), ("knn", best_knn)])

knn_pipe.fit(X_train_proc, y_train)

# %%
zero_imputer.fit(X)

zero_X = zero_imputer.transform(X)
knn_pipe2 = Pipeline([("scaler", StandardScaler()), 
                      ("knn", KNeighborsClassifier(n_neighbors=6))])

knn_pipe2.fit(zero_X, y) 

zero_X_cols = zero_X.columns.to_list()

# %%
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=42, max_iter=1000, class_weight="balanced", n_jobs=-1)
clf.fit(X_proc, y)

importances = permutation_importance(clf, X_proc, y, random_state=42, scoring="roc_auc")
importances

# %%
# pd.options.display.float_format = '{:.4f}'.format # global rounding

importance_series = pd.Series(importances.importances_mean, index=X_proc.columns)
importance_series.sort_values(ascending=False).round(6)

# %%
importance_mask = importance_series > 0
importance_mask

# %%
X_imp = X_proc.loc[:, importance_mask]
X_imp.shape

# %% [markdown]
# ## Ridge regression classifier

# %%
# AttributeError: 'RidgeClassifier' object has no attribute 'predict_proba'


# ridge = RidgeClassifier(random_state=42, class_weight="balanced")
# ridge.fit(X_train, y_train)

# ridge_results = eval_classification(ridge, X_train, y_train, X_test, y_test,
#                               model_name="Ridge Classifier")
# # , results_frame=rf_cv_results

# %%
# AttributeError: 'RidgeClassifierCV' object has no attribute 'predict_proba'


# ridge_cv = RidgeClassifierCV(class_weight="balanced", scoring="roc_auc")
# ridge_cv.fit(X_train, y_train)

# ridge_cv_results = eval_classification(ridge_cv, X_train, y_train, X_test, y_test,
#                               model_name="Ridge Classifier CV", roc_auc_average="macro")
# # , results_frame=rf_cv_results

# %% [markdown]
# ## K Nearest Neighbors

# %%
# knn = KNeighborsClassifier().fit(X_train, y_train)

# knn_results = eval_classification(knn, X_train, y_train, X_test, y_test,
#                                   model_name="K Nearest Neighbors", results_frame=dt_cv_results)

# %%
# knn.get_params()

# %%
# knn_params = {'n_neighbors': range(3,8),
#               'leaf_size': [10, 20, 30, 40, 50]}
# knn_gs = GridSearchCV(knn, knn_params, scoring="roc_auc")
# knn_gs.fit(X_train, y_train)
# knn_cv = knn_gs.best_estimator_.fit(X_train, y_train)

# knn_cv_results = eval_classification(knn_cv, X_train, y_train, X_test, y_test,
#                                   model_name="K Nearest Neighbors CV", results_frame=knn_results)

# %%
test_data_file = "application_test.csv"
test_data = pd.read_csv(local_prepend + input_path + test_data_file)

test_data = pd.merge(test_data, bureau, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, previous_application, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, POS_CASH_balance, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])
test_data = pd.merge(test_data, credit_card_balance, how="left", on="SK_ID_CURR")
test_data = test_data.drop_duplicates(subset=["SK_ID_CURR"])

ids = test_data.pop("SK_ID_CURR")

test_data = test_data[zero_X_cols]

zero_test = zero_imputer.transform(test_data)

preds = knn_pipe2.predict_proba(zero_test)[:,1]

output = pd.DataFrame({"SK_ID_CURR": ids,
                       "TARGET": preds})

# %%
output

# %%
sample_submission_file = "sample_submission.csv"
sample_submission_df = pd.read_csv(local_prepend + input_path + sample_submission_file)
sample_submission_df["TARGET"] = preds
sample_submission_df.to_csv("00f_more_merges.csv", index=False)
sample_submission_df.head()

# %%
# # create a logistic regression
# log_reg = LogisticRegression(max_iter=100000, random_state=42)
# log_reg.fit(X_train_proc, y_train)
# log_reg.predict_proba(X_test_proc)[:,0]

# %%
eval_classification(best_knn, X_train_proc, y_train, X_test_proc, y_test, model_name="best knn", results_frame=None,
                        pos_label=1, average="binary")

# %%
from imblearn.over_sampling import RandomOverSampler, SMOTE, ADASYN
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline

# %%
y_train.value_counts()

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier

clf = LogisticRegression(max_iter=1000,
                         class_weight="balanced",
                         random_state=42,
                         n_jobs=-1)


sfs = SequentialFeatureSelector(clf, tol=-0.01156, direction="backward", scoring="roc_auc", n_jobs=-1)
sfs.fit(X_proc, y)
sfs.get_support()
sfs.transform(X_proc).shape

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
X_new = SelectKBest(f_classif, k="all").fit_transform(X_proc, y)
X_new.shape

# %%
X.columns.difference(X_non_co.columns).to_list()

# %% [markdown]
# # Threshold Tuning

# %%
tuned_clf = TunedThresholdClassifierCV(stacked_clf, random_state=42,
                                       scoring="roc_auc", n_jobs=-1).fit(X_train, y_train)

tuned_clf_results = eval_classification(tuned_clf, X_train, y_train, X_test, y_test,
                                  model_name="Tuned Threshold Classifer", results_frame=stacked_clf_results)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[54], line 2
#
#       1 tuned_clf = TunedThresholdClassifierCV(stacked_clf, random_state=42,
#
# ----> 2                                        scoring="roc_auc", n_jobs=-1).fit(X_train, y_train)
#
#       4 tuned_clf_results = eval_classification(tuned_clf, X_train, y_train, X_test, y_test,
#
#       5                                   model_name="Tuned Threshold Classifer", results_frame=stacked_clf_results)
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#
#    1382     estimator._validate_params()
#
#    1384 with config_context(
#
#    1385     skip_parameter_validation=(
#
#    1386         prefer_skip_nested_validation or global_skip_validation
#
#    1387     )
#
#    1388 ):
#
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/model_selection/_classification_threshold.py:135, in BaseThresholdClassifier.fit(self, X, y, **params)
#
#     130 if y_type != "binary":
#
#     131     raise ValueError(
#
#     132         f"Only binary classification is supported. Unknown label type: {y_type}"
#
#     133     )
#
# --> 135 self._fit(X, y, **params)
#
#     137 if hasattr(self.estimator_, "n_features_in_"):
#
#     138     self.n_features_in_ = self.estimator_.n_features_in_
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/model_selection/_classification_threshold.py:783, in TunedThresholdClassifierCV._fit(self, X, y, **params)
#
#     776         fit_params_train = _check_method_params(
#
#     777             X, routed_params.estimator.fit, indices=train_idx
#
#     778         )
#
#     780     self.estimator_.fit(X_train, y_train, **fit_params_train)
#
#     782 cv_scores, cv_thresholds = zip(
#
# --> 783     *Parallel(n_jobs=self.n_jobs)(
#
#     784         delayed(_fit_and_score_over_thresholds)(
#
#     785             clone(classifier) if cv != "prefit" else classifier,
#
#     786             X,
#
#     787             y,
#
#     788             fit_params=routed_params.estimator.fit,
#
#     789             train_idx=train_idx,
#
#     790             val_idx=val_idx,
#
#     791             curve_scorer=self._curve_scorer,
#
#     792             score_params=routed_params.scorer.score,
#
#     793         )
#
#     794         for train_idx, val_idx in splits
#
#     795     )
#
#     796 )
#
#     798 if any(np.isclose(th[0], th[-1]) for th in cv_thresholds):
#
#     799     raise ValueError(
#
#     800         "The provided estimator makes constant predictions. Therefore, it is "
#
#     801         "impossible to optimize the decision threshold."
#
#     802     )
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#
#      72 config = get_config()
#
#      73 iterable_with_config = (
#
#      74     (_with_config(delayed_func, config), args, kwargs)
#
#      75     for delayed_func, args, kwargs in iterable
#
#      76 )
#
# ---> 77 return super().__call__(iterable_with_config)
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#
#    2001 # The first item from the output is blank, but it makes the interpreter
#
#    2002 # progress until it enters the Try/Except block of the generator and
#
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#
#    2004 # dispatch of the tasks to the workers.
#
#    2005 next(output)
#
# -> 2007 return output if self.return_generator else list(output)
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#
#    1647     yield
#
#    1649     with self._backend.retrieval_context():
#
# -> 1650         yield from self._retrieve()
#
#    1652 except GeneratorExit:
#
#    1653     # The generator has been garbage collected before being fully
#
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#
#    1655     # the user if necessary.
#
#    1656     self._exception = True
#
#
#
# File /opt/anaconda3/envs/datascience/lib/python3.12/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#
#    1758 # async callbacks to progress.
#
#    1759 if ((len(self._jobs) == 0) or
#
#    1760     (self._jobs[0].get_status(
#
#    1761         timeout=self.timeout) == TASK_PENDING)):
#
# -> 1762     time.sleep(0.01)
#
#    1763     continue
#
#    1765 # We need to be careful: the job list can be filling up as
#
#    1766 # we empty it and Python list are not thread-safe by
#
#    1767 # default hence the use of the lock
#
#
#
# KeyboardInterrupt:

# %%
X_non_co = non_co_pipe.transform(X)

# %%
from sklearn.feature_selection import SelectFromModel
set_config(transform_output="pandas")

selector = SelectFromModel(clf, threshold=0, max_features=40)

selector.fit(X_train_proc, y_train)

X_train_sel = selector.transform(X_train_proc)
X_train_sel

sel_pipe = Pipeline([("preprocessor", preprocessor),
                     ("selector", selector),
                     ("model", RandomForestClassifier(random_state=42))])

sel_pipe.fit(X_train, y_train)

results_sel = eval_classification(sel_pipe, X_train, y_train, X_test, y_test, model_name="RF SelectFromModel", results_frame=results_imp)

results_sel

# %%
0.000038
0.01156
